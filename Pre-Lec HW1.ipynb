# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)
df.isna().sum()

# %%
df.shape
# Out:
# (391, 11)

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Checking the number of rows and columns
rows, columns = df.shape
print(f"The DataFrame has {rows} rows and {columns} columns.")
# Out:
# The DataFrame has 391 rows and 11 columns.

# %%
shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 shape
#
# NameError: name 'shape' is not defined

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Summary of the dataset
print(df.info())          # General information including columns, non-null values, and data types
print(df.describe())      # Statistical summary for numerical columns

# Example of summary for categorical columns (if any)
for column in df.select_dtypes(include=['object']).columns:
    print(f"\nValue counts for {column}:")
    print(df[column].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_n        391 non-null    int64
#  1   id           390 non-null    object
#  2   name         391 non-null    object
#  3   gender       391 non-null    object
#  4   species      391 non-null    object
#  5   birthday     391 non-null    object
#  6   personality  391 non-null    object
#  7   song         380 non-null    object
#  8   phrase       391 non-null    object
#  9   full_id      391 non-null    object
#  10  url          391 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 33.7+ KB
# None
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000
#
# Value counts for id:
# id
# admiral    1
# mott       1
# paula      1
# patty      1
# ...

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Basic information about the dataset (rows, columns, and data types)
print("Basic Information:")
print(df.info())

# Checking missing values in each column
print("\nMissing Values:")
print(df.isna().sum())

# Descriptive statistics for numeric columns
print("\nSummary Statistics for Numerical Columns:")
print(df.describe())

# For categorical columns, show the most frequent values
print("\nValue Counts for Categorical Columns:")
for column in df.select_dtypes(include=['object']).columns:
    print(f"\n{column} value counts:")
    print(df[column].value_counts().head())  # Show top 5 most frequent values
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_n        391 non-null    int64
#  1   id           390 non-null    object
#  2   name         391 non-null    object
#  3   gender       391 non-null    object
#  4   species      391 non-null    object
#  5   birthday     391 non-null    object
#  6   personality  391 non-null    object
#  7   song         380 non-null    object
#  8   phrase       391 non-null    object
#  9   full_id      391 non-null    object
#  10  url          391 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 33.7+ KB
# None
#
# Missing Values:
# row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# ...

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)

# Check dataset size
print("Dataset shape (rows, columns):", df.shape)

# Describe numerical columns
describe = df.describe()
print("\nNumber of columns analyzed by df.describe():", describe.shape[1])

# Compare "count" values from df.describe() with total number of rows
print("\nCount of non-null values in numerical columns:")
print(describe.loc['count'])

# Compare with total number of rows in the dataset
print("\nTotal number of rows in the dataset:", df.shape[0])
# Out:
# Dataset shape (rows, columns): (391, 11)
#
# Number of columns analyzed by df.describe(): 1
#
# Count of non-null values in numerical columns:
# row_n    391.0
# Name: count, dtype: float64
#
# Total number of rows in the dataset: 391

# %%
print(df.shape)
# Out:
# (391, 11)

# %%
summary = df.describe()  # Calls the method and performs the operation

# %% [markdown]
# 4. df.shape defines the total number of rows and columns in a dataset
#    df.describe() provides summary statistics for numerical columns
#    If there are missing values in a column, df.describe() will show a lower count than the total number of rows reported by df.shape
#    As mentioned, non-numeric columns are excluded from df.describe() by default, which can lead to fewer columns being summarized compared to the total number of columns reported by df.shape

# %% [markdown]
# 5. attribute is a value that holds a object's properties and a method is a function assocuateda  with a object that performs operations on the object's data. Attribute is static so it doesnt change the object while method can change or return the value of an object.

# %% [markdown]
# 6.
# Count: The number of entries.
# Mean: The average of the values in each column.
# Std (Standard Deviation): A measure of the amount of variation or dispersion in the values of a column.
# Min: The smallest value in each column.
# 25% (First Quartile): The value below which 25% of the data falls.
# 50% (Median): The middle value of the data when it is sorted. Half of the values are below this point and half are above it.
# 75% (Third Quartile): The value below which 75% of the data falls.
# Max: The largest value in each column.

# %% [markdown]
# 7.
#  1.Consider a data sheet where the columns are the names of the students and the marks that they have gotten throughtout the semestr. Each row would represent a single entry of a student's mark throught the term. If a student had dropped out in the middle of the semester,then a few columns for the marks of certaiun examinations might be empty. In this case df.dropna() might work better thamn del df['col']
#
#  2.Consider a data set that contains the results for a survey. The columns would inlcude the name of the particpant and answers to each question. If at the end of the survey, there was a optional question, there would be a lot of missing entries in that column. In this case the best solution would be to del def['col'] rather than df.dropna()
#
#  3. This is to avoid deleted more information than required. If del def['col'] is completed first, we are deleting a lot of empty cells
#
#  4. If we have a dataset with the columns age, country, profession and hobbies, and we find more than 50% of missing values in

# %% [markdown]
# 8. 1.
# Grouping by col1: The df.groupby("col1") part of the command groups the DataFrame df based on the unique values in the column col1. This creates separate groups for each different value in col1.
# Selecting col2: The ["col2"] part selects the column col2 from each group created in the previous step.
# Applying describe(): The describe() method is then applied to the selected column col2 within each group.
